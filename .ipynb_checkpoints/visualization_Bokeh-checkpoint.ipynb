# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity 

from bokeh.io import show, curdoc, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, Select, Paragraph, TextInput
from bokeh.layouts import widgetbox, column, row
from ipywidgets import interact

# %%
df = pd.read_csv('cosmetic_tsne.csv')
df.sample(5)
# Out:
#      index                    Label        brand  \
# 104    150  Moisturizer_Combination        MURAD
# 308    160          Moisturizer_Dry        FRESH
# 183    268  Moisturizer_Combination   JACK BLACK
# 187    277  Moisturizer_Combination  TATA HARPER
# 383    287          Moisturizer_Dry     ALGENIST
#
#                                      name  price  rank  \
# 104     Oil-Control Mattifier SPF 15 PA++     40   4.2
# 308             Black Tea Age-Delay Cream     90   4.2
# 183     Clean Break™ Oil-Free Moisturizer     30   4.5
# 187            Retinoic Nutrient Face Oil     48   4.3
# 383  POWER Recharging Night Pressed Serum     95   4.4
#
#                                            ingredients  Combination  Dry  \
# 104  -Oil-Control Complex®: Helps diminish shine wh...            1    0
# 308                           Visit the Fresh boutique            0    1
# 183  Water, Cyclopentasiloxane, Octyldodecyl Neopen...            1    0
# 187                     Visit the Tata Harper boutique            1    1
# 383  -Alguronic Acid: Reduces the appearance of fin...            1    1
#
#      Full  Light  Matte  Medium  Natural  Normal  Oily  Radiant  Sensitive  \
# 104     0      0      0       0        0       0     1        0          0
# 308     0      0      0       0        0       1     0        0          0
# 183     0      0      0       0        0       1     1        0          1
# 187     0      0      0       0        0       1     1        0          1
# 383     0      0      0       0        0       1     1        0          1
#
#              X           Y
# 104 -26.775784  106.938470
# 308   2.585930    0.259202
# 183  39.555470    2.790104
# 187  17.715858   -2.150617
# 383  42.281830   21.431986

# %% [markdown]
# ## Visualization

# %%
df.Label.unique()
# option1_option2 combinations (6*5 = 30)
# Out:
# array(['Moisturizer_Combination', 'Moisturizer_Dry', 'Moisturizer_Full',
#        'Moisturizer_Light', 'Moisturizer_Matte'], dtype=object)

# %%
option_1 = ['Moisturizer', 'Cleanser', 'Treatment', 'Mask', 'Eye', 'SPF']
option_2 = ['Combination','Normal','Dry', 'Oily','Sensitive']

# %%
# make connection
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# make source
# scatter bokeh plot

source = ColumnDataSource(df)
plot = figure(x_axis_label = '1', y_axis_label = '2', 
             width = 500, height = 400, tools = 'pan, box_zoom, wheel_zoom')

plot.circle(x= 'X', y = 'Y', source = source, size = 10, color = "#FA8072", alpha = .8)
plot.background_fill_color = "#FAEBD7"
plot.background_fill_alpha = 0.1

# %%
# add hover tool 

hover = HoverTool(tooltips = [
    ('Item', '@name'),
    ('brand', '@brand'),
    ('Price', '$ @price'),
    ('Rank', '@rank')
])

plot.add_tools(hover)

# %%
def update(op1 = option_1[0], op2 = option_2[0]):
    a_b = op1 + '_' + op2
    new_data = {
        'X': df[df['Label'] == a_b]['X'],
        'Y': df[df['Label'] == a_b]['Y'],
        'name': df[df['Label'] == a_b]['name'],
        'brand': df[df['Label'] == a_b]['brand'],
        'price': df[df['Label'] == a_b]['price'],
        'rank': df[df['Label'] == a_b]['rank'],
    }
    source.data = new_data
    push_notebook()

# %%
output_notebook()

interact(update, op1 = option_1, op2 = option_2)
show(plot, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1036">Loading BokehJS ...</span>
#     </div>
# interactive(children=(Dropdown(description='op1', options=('Moisturizer', 'Cleanser', 'Treatment', 'Mask', 'Ey…
#   <div class="bk-root" id="60abee31-63d4-41f9-9524-ea135d5b56f9" data-root-id="1003"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %%
# a plane for type of product vs price range
